# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
img = cv2.imread('./img/watch.jpeg',cv2.IMREAD_GRAYSCALE)
#img = cv2.imread('./img/watch.jpeg',0)
#cv2.imshow('image',img)
#cv2.IMREAD_GRAYSCALE = 0
#IMREAD_COLOR = 1
#IMREAD_UNCHANGED = -1

plt.imshow(img,cmap='gray',interpolation='bicubic')
